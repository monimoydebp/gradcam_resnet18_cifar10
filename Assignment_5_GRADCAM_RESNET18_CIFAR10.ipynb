# %% [markdown]
# # Assignment 5:
#
# In this assignment, I have to do the following:
# - Use pretrained RESNET 18 model and train on CIFAR10
# - Get a list of 50 misclassified images
# - Create a gallery of GradCam results

# %% [markdown]
# ## Import all the Keras libraries

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout,  GlobalAveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Mount the google drive to save the model

# %%
 # Mount the google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ## Load the  train features, train labels, test features, train labels from CIFAR10 dataset

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %% [markdown]
# ## Define class names and display
# * Define the 10 classes as airplane, automobile, bird, cat, deer, dog, frog, horse, ship, truck
# * Display one element from each class

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %% [markdown]
# ## Define a method for diplaying model history
# Define a method plot_model_history for displaying model history which will do the following
# * Plot Model accuracy (both the training and validation accuracy) vs number of epochs.
# * Model loss ((both the training and validation accuracy) vs number of epoch

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %% [markdown]
# ## Define a method for calculate accuracy
#
# Define a mehod accuracy which will calculate accuracy from model
# * Get True class
# * Get Predicted class
# * Get numbe of correc predictions
# * Divide number of correct predictions by total number of elements to get the accuracy

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %% [markdown]
# ## Perform pixel normalization of features and one hot encoding of train and test
#
# * Perform pixel normalization by dividing train and test features by 255
# * Use to_categorical method of np_utils to use one hot encoding to Convert the train_labels, test_labels to 10 dimensional categorical matrix

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
test_features.shape
# Out:
# (10000, 32, 32, 3)

# %% [markdown]
# ## Install RESNET18 pretrained model
# - Install RESNET18 pretrainded model on Imagenet from https://github.com/qubvel/classification_models.git

# %%
# !pip install git+https://github.com/qubvel/classification_models.git
# Out:
# Collecting git+https://github.com/qubvel/classification_models.git
#   Cloning https://github.com/qubvel/classification_models.git to /tmp/pip-req-build-a3_07m53
#   Running command git clone -q https://github.com/qubvel/classification_models.git /tmp/pip-req-build-a3_07m53
#   Running command git submodule update --init --recursive -q
# Requirement already satisfied: keras>=2.1.0 in /usr/local/lib/python3.6/dist-packages (from image-classifiers==0.2.2) (2.2.4)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.0->image-classifiers==0.2.2) (1.12.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.0->image-classifiers==0.2.2) (1.1.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.0->image-classifiers==0.2.2) (1.16.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.0->image-classifiers==0.2.2) (2.8.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.0->image-classifiers==0.2.2) (1.0.8)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.0->image-classifiers==0.2.2) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras>=2.1.0->image-classifiers==0.2.2) (1.3.0)
# Building wheels for collected packages: image-classifiers
#   Building wheel for image-classifiers (setup.py) ... done
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qisv_33c/wheels/de/2b/fd/29a6d33edb8c28bc7d94e95ea1d39c9a218ac500a3cfb1b197
# Successfully built image-classifiers
# Installing collected packages: image-classifiers
# Successfully installed image-classifiers-0.2.2

# %% [markdown]
# ## Use Transfer Learning to use pretrained model to work on CIFAR10
#
# Since pretrained model is trained on imagenet butI need to use model to work on CIFAR10.I will do the following steps below to chnage the model work on CIFAR10
#
#
# * Load the base model fro RESNET18 pretrained on imagenet without top with inpuce share chnaged to dimensions 32x32x32
# * Add 1x1 convolution layer custom_1_1_layer with 10 filters which is the number of classes for CIFAR10
# * Add Global Average Pooling Layer custom_global_average_pooling
# * Add softmax activation layer custom_softmax
# * Get the New model

# %%
from classification_models.resnet import ResNet18, preprocess_input
from keras.models import Model, load_model
from keras.layers import Activation, Flatten, Dense, Dropout, Input, Concatenate, GlobalAveragePooling2D
num_classes = 10

# build model
base_model = ResNet18(input_shape=(32,32,3), weights='imagenet', include_top=False)
x = Convolution2D(num_classes, 1, 1, use_bias=False, name='custom_1_1_layer')(base_model.output) 
x = GlobalAveragePooling2D(name='custom_global_average_pooling')(x)
output = Activation('softmax', name='custom_softmax')(x)
model = Model(inputs=[base_model.input], outputs=[output])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0712 02:05:28.507779 140014522099584 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0712 02:05:28.550945 140014522099584 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0712 02:05:28.552329 140014522099584 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0712 02:05:28.553640 140014522099584 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0712 02:05:28.554909 140014522099584 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0712 02:05:31.118485 140014522099584 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0712 02:05:31.393592 140014522099584 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet18_imagenet_1000_no_top.h5
# 44924928/44920640 [==============================] - 3s 0us/step
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1), use_bias=False, name="custom_1_1_layer")`

# %% [markdown]
# ## Summarize the model

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, 32, 32, 3)    9           data[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 38, 38, 3)    0           bn_data[0][0]
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, 16, 16, 64)   9408        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, 16, 16, 64)   256         conv0[0][0]
# __________________________________________________________________________________________________
# relu0 (Activation)              (None, 16, 16, 64)   0           bn0[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 18, 18, 64)   0           relu0[0][0]
# __________________________________________________________________________________________________
# pooling0 (MaxPooling2D)         (None, 8, 8, 64)     0           zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn1 (BatchNormaliz (None, 8, 8, 64)     256         pooling0[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu1 (Activation) (None, 8, 8, 64)     0           stage1_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 10, 10, 64)   0           stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv1 (Conv2D)     (None, 8, 8, 64)     36864       zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn2 (BatchNormaliz (None, 8, 8, 64)     256         stage1_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu2 (Activation) (None, 8, 8, 64)     0           stage1_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 10, 10, 64)   0           stage1_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv2 (Conv2D)     (None, 8, 8, 64)     36864       zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_sc (Conv2D)        (None, 8, 8, 64)     4096        stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 8, 8, 64)     0           stage1_unit1_conv2[0][0]
#                                                                  stage1_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn1 (BatchNormaliz (None, 8, 8, 64)     256         add_1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu1 (Activation) (None, 8, 8, 64)     0           stage1_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 10, 10, 64)   0           stage1_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv1 (Conv2D)     (None, 8, 8, 64)     36864       zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn2 (BatchNormaliz (None, 8, 8, 64)     256         stage1_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu2 (Activation) (None, 8, 8, 64)     0           stage1_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 10, 10, 64)   0           stage1_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv2 (Conv2D)     (None, 8, 8, 64)     36864       zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 8, 8, 64)     0           stage1_unit2_conv2[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn1 (BatchNormaliz (None, 8, 8, 64)     256         add_2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu1 (Activation) (None, 8, 8, 64)     0           stage2_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 10, 10, 64)   0           stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv1 (Conv2D)     (None, 4, 4, 128)    73728       zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn2 (BatchNormaliz (None, 4, 4, 128)    512         stage2_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu2 (Activation) (None, 4, 4, 128)    0           stage2_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 6, 6, 128)    0           stage2_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv2 (Conv2D)     (None, 4, 4, 128)    147456      zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_sc (Conv2D)        (None, 4, 4, 128)    8192        stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 4, 4, 128)    0           stage2_unit1_conv2[0][0]
#                                                                  stage2_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn1 (BatchNormaliz (None, 4, 4, 128)    512         add_3[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu1 (Activation) (None, 4, 4, 128)    0           stage2_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 6, 6, 128)    0           stage2_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv1 (Conv2D)     (None, 4, 4, 128)    147456      zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn2 (BatchNormaliz (None, 4, 4, 128)    512         stage2_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu2 (Activation) (None, 4, 4, 128)    0           stage2_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 6, 6, 128)    0           stage2_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv2 (Conv2D)     (None, 4, 4, 128)    147456      zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 4, 4, 128)    0           stage2_unit2_conv2[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn1 (BatchNormaliz (None, 4, 4, 128)    512         add_4[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu1 (Activation) (None, 4, 4, 128)    0           stage3_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 6, 6, 128)    0           stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv1 (Conv2D)     (None, 2, 2, 256)    294912      zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn2 (BatchNormaliz (None, 2, 2, 256)    1024        stage3_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu2 (Activation) (None, 2, 2, 256)    0           stage3_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 4, 4, 256)    0           stage3_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv2 (Conv2D)     (None, 2, 2, 256)    589824      zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_sc (Conv2D)        (None, 2, 2, 256)    32768       stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 2, 2, 256)    0           stage3_unit1_conv2[0][0]
#                                                                  stage3_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn1 (BatchNormaliz (None, 2, 2, 256)    1024        add_5[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu1 (Activation) (None, 2, 2, 256)    0           stage3_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 4, 4, 256)    0           stage3_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv1 (Conv2D)     (None, 2, 2, 256)    589824      zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn2 (BatchNormaliz (None, 2, 2, 256)    1024        stage3_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu2 (Activation) (None, 2, 2, 256)    0           stage3_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 4, 4, 256)    0           stage3_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv2 (Conv2D)     (None, 2, 2, 256)    589824      zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 2, 2, 256)    0           stage3_unit2_conv2[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn1 (BatchNormaliz (None, 2, 2, 256)    1024        add_6[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu1 (Activation) (None, 2, 2, 256)    0           stage4_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 4, 4, 256)    0           stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv1 (Conv2D)     (None, 1, 1, 512)    1179648     zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn2 (BatchNormaliz (None, 1, 1, 512)    2048        stage4_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu2 (Activation) (None, 1, 1, 512)    0           stage4_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 3, 3, 512)    0           stage4_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv2 (Conv2D)     (None, 1, 1, 512)    2359296     zero_padding2d_16[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_sc (Conv2D)        (None, 1, 1, 512)    131072      stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 1, 1, 512)    0           stage4_unit1_conv2[0][0]
#                                                                  stage4_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn1 (BatchNormaliz (None, 1, 1, 512)    2048        add_7[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu1 (Activation) (None, 1, 1, 512)    0           stage4_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 3, 3, 512)    0           stage4_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv1 (Conv2D)     (None, 1, 1, 512)    2359296     zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn2 (BatchNormaliz (None, 1, 1, 512)    2048        stage4_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu2 (Activation) (None, 1, 1, 512)    0           stage4_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_18 (ZeroPadding2 (None, 3, 3, 512)    0           stage4_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv2 (Conv2D)     (None, 1, 1, 512)    2359296     zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 1, 1, 512)    0           stage4_unit2_conv2[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 1, 1, 512)    2048        add_8[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, 1, 1, 512)    0           bn1[0][0]
# __________________________________________________________________________________________________
# custom_1_1_layer (Conv2D)       (None, 1, 1, 10)     5120        relu1[0][0]
# __________________________________________________________________________________________________
# custom_global_average_pooling ( (None, 10)           0           custom_1_1_layer[0][0]
# __________________________________________________________________________________________________
# custom_softmax (Activation)     (None, 10)           0           custom_global_average_pooling[0][
# ==================================================================================================
# Total params: 11,192,009
# Trainable params: 11,184,067
# Non-trainable params: 7,942
# __________________________________________________________________________________________________

# %% [markdown]
# ## Visually Display the Model Architecture

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png')

# %%
from IPython.display import Image
Image(filename='model.png')

# %% [markdown]
# ## Compile the Model

# %%
model.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# W0712 02:05:59.002302 140014522099584 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# ## Train the  Model and get the Metrics (Accuracy, Loss) and Plot the model history
#
#  * Train the model using fit_generator method
#  * Plot the model history

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from keras.callbacks import ModelCheckpoint
from keras.models import load_model



datagen = ImageDataGenerator(zoom_range=0.0,horizontal_flip=False, featurewise_center=True, featurewise_std_normalization=True)

callbacks_list=[]
model_save_path= "/content/drive/My Drive/assignment_5_resnet_cifar10.h5"
callbacks_list.append(ModelCheckpoint(model_save_path, monitor='val_acc', verbose=1, save_best_only=True, mode='max'))


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1, callbacks=callbacks_list)

end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, callbacks=[<keras.ca..., steps_per_epoch=390, epochs=100)`
# W0712 02:06:05.463668 140014522099584 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:716: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py:724: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# 390/390 [==============================] - 22s 56ms/step - loss: 1.1854 - acc: 0.5938 - val_loss: 0.9052 - val_acc: 0.6894
#
# Epoch 00001: val_acc improved from -inf to 0.68940, saving model to /content/drive/My Drive/assignment_5_resnet_cifar10.h5
# Epoch 2/100
# 390/390 [==============================] - 17s 43ms/step - loss: 0.7337 - acc: 0.7441 - val_loss: 0.7539 - val_acc: 0.7451
#
# Epoch 00002: val_acc improved from 0.68940 to 0.74510, saving model to /content/drive/My Drive/assignment_5_resnet_cifar10.h5
# Epoch 3/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.5734 - acc: 0.8010 - val_loss: 0.7268 - val_acc: 0.7568
#
# Epoch 00003: val_acc improved from 0.74510 to 0.75680, saving model to /content/drive/My Drive/assignment_5_resnet_cifar10.h5
# Epoch 4/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.4565 - acc: 0.8411 - val_loss: 0.7089 - val_acc: 0.7704
#
# Epoch 00004: val_acc improved from 0.75680 to 0.77040, saving model to /content/drive/My Drive/assignment_5_resnet_cifar10.h5
# Epoch 5/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.3556 - acc: 0.8793 - val_loss: 0.7152 - val_acc: 0.7717
#
# Epoch 00005: val_acc improved from 0.77040 to 0.77170, saving model to /content/drive/My Drive/assignment_5_resnet_cifar10.h5
# Epoch 6/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.2771 - acc: 0.9078 - val_loss: 0.7348 - val_acc: 0.7728
#
# Epoch 00006: val_acc improved from 0.77170 to 0.77280, saving model to /content/drive/My Drive/assignment_5_resnet_cifar10.h5
# Epoch 7/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.2098 - acc: 0.9318 - val_loss: 0.7588 - val_acc: 0.7763
#
# Epoch 00007: val_acc improved from 0.77280 to 0.77630, saving model to /content/drive/My Drive/assignment_5_resnet_cifar10.h5
# Epoch 8/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1572 - acc: 0.9519 - val_loss: 0.7831 - val_acc: 0.7766
#
# Epoch 00008: val_acc improved from 0.77630 to 0.77660, saving model to /content/drive/My Drive/assignment_5_resnet_cifar10.h5
# Epoch 9/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.1180 - acc: 0.9672 - val_loss: 0.8457 - val_acc: 0.7710
#
# Epoch 00009: val_acc did not improve from 0.77660
# Epoch 10/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0885 - acc: 0.9763 - val_loss: 0.8504 - val_acc: 0.7816
#
# Epoch 00010: val_acc improved from 0.77660 to 0.78160, saving model to /content/drive/My Drive/assignment_5_resnet_cifar10.h5
# Epoch 11/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0679 - acc: 0.9824 - val_loss: 0.8859 - val_acc: 0.7763
#
# Epoch 00011: val_acc did not improve from 0.78160
# Epoch 12/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0549 - acc: 0.9870 - val_loss: 0.9079 - val_acc: 0.7786
#
# Epoch 00012: val_acc did not improve from 0.78160
# Epoch 13/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0428 - acc: 0.9902 - val_loss: 0.9422 - val_acc: 0.7779
#
# Epoch 00013: val_acc did not improve from 0.78160
# Epoch 14/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0353 - acc: 0.9920 - val_loss: 0.9642 - val_acc: 0.7791
#
# Epoch 00014: val_acc did not improve from 0.78160
# Epoch 15/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0308 - acc: 0.9933 - val_loss: 0.9876 - val_acc: 0.7792
#
# Epoch 00015: val_acc did not improve from 0.78160
# Epoch 16/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0273 - acc: 0.9944 - val_loss: 1.0060 - val_acc: 0.7838
#
# Epoch 00016: val_acc improved from 0.78160 to 0.78380, saving model to /content/drive/My Drive/assignment_5_resnet_cifar10.h5
# Epoch 17/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0238 - acc: 0.9948 - val_loss: 1.0221 - val_acc: 0.7807
#
# Epoch 00017: val_acc did not improve from 0.78380
# Epoch 18/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0202 - acc: 0.9962 - val_loss: 1.0385 - val_acc: 0.7815
#
# Epoch 00018: val_acc did not improve from 0.78380
# Epoch 19/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0180 - acc: 0.9968 - val_loss: 1.0582 - val_acc: 0.7836
#
# Epoch 00019: val_acc did not improve from 0.78380
# Epoch 20/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0164 - acc: 0.9967 - val_loss: 1.0614 - val_acc: 0.7798
#
# Epoch 00020: val_acc did not improve from 0.78380
# Epoch 21/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0144 - acc: 0.9972 - val_loss: 1.0702 - val_acc: 0.7806
#
# Epoch 00021: val_acc did not improve from 0.78380
# Epoch 22/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0145 - acc: 0.9971 - val_loss: 1.0840 - val_acc: 0.7822
#
# Epoch 00022: val_acc did not improve from 0.78380
# Epoch 23/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0105 - acc: 0.9982 - val_loss: 1.0902 - val_acc: 0.7837
#
# Epoch 00023: val_acc did not improve from 0.78380
# Epoch 24/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0101 - acc: 0.9982 - val_loss: 1.1043 - val_acc: 0.7806
#
# Epoch 00024: val_acc did not improve from 0.78380
# Epoch 25/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0108 - acc: 0.9980 - val_loss: 1.1247 - val_acc: 0.7813
#
# Epoch 00025: val_acc did not improve from 0.78380
# Epoch 26/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0095 - acc: 0.9982 - val_loss: 1.1192 - val_acc: 0.7852
#
# Epoch 00026: val_acc improved from 0.78380 to 0.78520, saving model to /content/drive/My Drive/assignment_5_resnet_cifar10.h5
# Epoch 27/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0090 - acc: 0.9983 - val_loss: 1.1315 - val_acc: 0.7844
#
# Epoch 00027: val_acc did not improve from 0.78520
# Epoch 28/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0091 - acc: 0.9983 - val_loss: 1.1376 - val_acc: 0.7841
#
# Epoch 00028: val_acc did not improve from 0.78520
# Epoch 29/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0079 - acc: 0.9986 - val_loss: 1.1419 - val_acc: 0.7858
#
# Epoch 00029: val_acc improved from 0.78520 to 0.78580, saving model to /content/drive/My Drive/assignment_5_resnet_cifar10.h5
# Epoch 30/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0076 - acc: 0.9986 - val_loss: 1.1515 - val_acc: 0.7868
#
# Epoch 00030: val_acc improved from 0.78580 to 0.78680, saving model to /content/drive/My Drive/assignment_5_resnet_cifar10.h5
# Epoch 31/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0074 - acc: 0.9988 - val_loss: 1.1550 - val_acc: 0.7862
#
# Epoch 00031: val_acc did not improve from 0.78680
# Epoch 32/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0064 - acc: 0.9988 - val_loss: 1.1660 - val_acc: 0.7836
#
# Epoch 00032: val_acc did not improve from 0.78680
# Epoch 33/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0063 - acc: 0.9989 - val_loss: 1.1666 - val_acc: 0.7834
#
# Epoch 00033: val_acc did not improve from 0.78680
# Epoch 34/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0059 - acc: 0.9990 - val_loss: 1.1753 - val_acc: 0.7833
#
# Epoch 00034: val_acc did not improve from 0.78680
# Epoch 35/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0061 - acc: 0.9988 - val_loss: 1.1828 - val_acc: 0.7843
#
# Epoch 00035: val_acc did not improve from 0.78680
# Epoch 36/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0059 - acc: 0.9989 - val_loss: 1.1948 - val_acc: 0.7840
#
# Epoch 00036: val_acc did not improve from 0.78680
# Epoch 37/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0054 - acc: 0.9990 - val_loss: 1.1876 - val_acc: 0.7839
#
# Epoch 00037: val_acc did not improve from 0.78680
# Epoch 38/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0047 - acc: 0.9993 - val_loss: 1.1954 - val_acc: 0.7866
#
# Epoch 00038: val_acc did not improve from 0.78680
# Epoch 39/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0047 - acc: 0.9993 - val_loss: 1.2018 - val_acc: 0.7879
#
# Epoch 00039: val_acc improved from 0.78680 to 0.78790, saving model to /content/drive/My Drive/assignment_5_resnet_cifar10.h5
# Epoch 40/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0057 - acc: 0.9987 - val_loss: 1.2131 - val_acc: 0.7873
#
# Epoch 00040: val_acc did not improve from 0.78790
# Epoch 41/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0048 - acc: 0.9992 - val_loss: 1.2212 - val_acc: 0.7868
#
# Epoch 00041: val_acc did not improve from 0.78790
# Epoch 42/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0045 - acc: 0.9992 - val_loss: 1.2124 - val_acc: 0.7843
#
# Epoch 00042: val_acc did not improve from 0.78790
# Epoch 43/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0042 - acc: 0.9993 - val_loss: 1.2185 - val_acc: 0.7849
#
# Epoch 00043: val_acc did not improve from 0.78790
# Epoch 44/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0046 - acc: 0.9990 - val_loss: 1.2193 - val_acc: 0.7867
#
# Epoch 00044: val_acc did not improve from 0.78790
# Epoch 45/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0048 - acc: 0.9990 - val_loss: 1.2114 - val_acc: 0.7906
#
# Epoch 00045: val_acc improved from 0.78790 to 0.79060, saving model to /content/drive/My Drive/assignment_5_resnet_cifar10.h5
# Epoch 46/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0050 - acc: 0.9989 - val_loss: 1.2289 - val_acc: 0.7879
#
# Epoch 00046: val_acc did not improve from 0.79060
# Epoch 47/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0046 - acc: 0.9990 - val_loss: 1.2373 - val_acc: 0.7875
#
# Epoch 00047: val_acc did not improve from 0.79060
# Epoch 48/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0043 - acc: 0.9991 - val_loss: 1.2265 - val_acc: 0.7872
#
# Epoch 00048: val_acc did not improve from 0.79060
# Epoch 49/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0043 - acc: 0.9991 - val_loss: 1.2457 - val_acc: 0.7870
#
# Epoch 00049: val_acc did not improve from 0.79060
# Epoch 50/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0040 - acc: 0.9993 - val_loss: 1.2433 - val_acc: 0.7886
#
# Epoch 00050: val_acc did not improve from 0.79060
# Epoch 51/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0042 - acc: 0.9990 - val_loss: 1.2491 - val_acc: 0.7855
#
# Epoch 00051: val_acc did not improve from 0.79060
# Epoch 52/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0039 - acc: 0.9993 - val_loss: 1.2458 - val_acc: 0.7861
#
# Epoch 00052: val_acc did not improve from 0.79060
# Epoch 53/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0035 - acc: 0.9993 - val_loss: 1.2519 - val_acc: 0.7865
#
# Epoch 00053: val_acc did not improve from 0.79060
# Epoch 54/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0037 - acc: 0.9993 - val_loss: 1.2509 - val_acc: 0.7888
#
# Epoch 00054: val_acc did not improve from 0.79060
# Epoch 55/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0033 - acc: 0.9994 - val_loss: 1.2612 - val_acc: 0.7887
#
# Epoch 00055: val_acc did not improve from 0.79060
# Epoch 56/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0037 - acc: 0.9991 - val_loss: 1.2508 - val_acc: 0.7910
#
# Epoch 00056: val_acc improved from 0.79060 to 0.79100, saving model to /content/drive/My Drive/assignment_5_resnet_cifar10.h5
# Epoch 57/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0030 - acc: 0.9995 - val_loss: 1.2616 - val_acc: 0.7884
#
# Epoch 00057: val_acc did not improve from 0.79100
# Epoch 58/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0032 - acc: 0.9994 - val_loss: 1.2687 - val_acc: 0.7860
#
# Epoch 00058: val_acc did not improve from 0.79100
# Epoch 59/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0036 - acc: 0.9993 - val_loss: 1.2738 - val_acc: 0.7887
#
# Epoch 00059: val_acc did not improve from 0.79100
# Epoch 60/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0032 - acc: 0.9994 - val_loss: 1.2712 - val_acc: 0.7879
#
# Epoch 00060: val_acc did not improve from 0.79100
# Epoch 61/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0031 - acc: 0.9994 - val_loss: 1.2697 - val_acc: 0.7869
#
# Epoch 00061: val_acc did not improve from 0.79100
# Epoch 62/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0029 - acc: 0.9995 - val_loss: 1.2686 - val_acc: 0.7889
#
# Epoch 00062: val_acc did not improve from 0.79100
# Epoch 63/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0031 - acc: 0.9994 - val_loss: 1.2762 - val_acc: 0.7893
#
# Epoch 00063: val_acc did not improve from 0.79100
# Epoch 64/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0027 - acc: 0.9995 - val_loss: 1.2748 - val_acc: 0.7909
#
# Epoch 00064: val_acc did not improve from 0.79100
# Epoch 65/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0027 - acc: 0.9995 - val_loss: 1.2763 - val_acc: 0.7878
#
# Epoch 00065: val_acc did not improve from 0.79100
# Epoch 66/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0025 - acc: 0.9995 - val_loss: 1.2819 - val_acc: 0.7901
#
# Epoch 00066: val_acc did not improve from 0.79100
# Epoch 67/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0023 - acc: 0.9997 - val_loss: 1.2818 - val_acc: 0.7912
#
# Epoch 00067: val_acc improved from 0.79100 to 0.79120, saving model to /content/drive/My Drive/assignment_5_resnet_cifar10.h5
# Epoch 68/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0023 - acc: 0.9997 - val_loss: 1.2818 - val_acc: 0.7899
#
# Epoch 00068: val_acc did not improve from 0.79120
# Epoch 69/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0028 - acc: 0.9996 - val_loss: 1.2874 - val_acc: 0.7891
#
# Epoch 00069: val_acc did not improve from 0.79120
# Epoch 70/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0024 - acc: 0.9996 - val_loss: 1.2912 - val_acc: 0.7878
#
# Epoch 00070: val_acc did not improve from 0.79120
# Epoch 71/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0025 - acc: 0.9995 - val_loss: 1.3120 - val_acc: 0.7862
#
# Epoch 00071: val_acc did not improve from 0.79120
# Epoch 72/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0029 - acc: 0.9993 - val_loss: 1.3038 - val_acc: 0.7902
#
# Epoch 00072: val_acc did not improve from 0.79120
# Epoch 73/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0031 - acc: 0.9993 - val_loss: 1.3051 - val_acc: 0.7914
#
# Epoch 00073: val_acc improved from 0.79120 to 0.79140, saving model to /content/drive/My Drive/assignment_5_resnet_cifar10.h5
# Epoch 74/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0023 - acc: 0.9996 - val_loss: 1.2930 - val_acc: 0.7905
#
# Epoch 00074: val_acc did not improve from 0.79140
# Epoch 75/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0021 - acc: 0.9997 - val_loss: 1.2968 - val_acc: 0.7904
#
# Epoch 00075: val_acc did not improve from 0.79140
# Epoch 76/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0019 - acc: 0.9997 - val_loss: 1.3030 - val_acc: 0.7913
#
# Epoch 00076: val_acc did not improve from 0.79140
# Epoch 77/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0022 - acc: 0.9996 - val_loss: 1.2989 - val_acc: 0.7915
#
# Epoch 00077: val_acc improved from 0.79140 to 0.79150, saving model to /content/drive/My Drive/assignment_5_resnet_cifar10.h5
# Epoch 78/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0023 - acc: 0.9996 - val_loss: 1.3034 - val_acc: 0.7893
#
# Epoch 00078: val_acc did not improve from 0.79150
# Epoch 79/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0016 - acc: 0.9998 - val_loss: 1.3098 - val_acc: 0.7903
#
# Epoch 00079: val_acc did not improve from 0.79150
# Epoch 80/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0018 - acc: 0.9998 - val_loss: 1.3082 - val_acc: 0.7879
#
# Epoch 00080: val_acc did not improve from 0.79150
# Epoch 81/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0022 - acc: 0.9996 - val_loss: 1.3176 - val_acc: 0.7884
#
# Epoch 00081: val_acc did not improve from 0.79150
# Epoch 82/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0017 - acc: 0.9996 - val_loss: 1.3038 - val_acc: 0.7885
#
# Epoch 00082: val_acc did not improve from 0.79150
# Epoch 83/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0018 - acc: 0.9997 - val_loss: 1.3064 - val_acc: 0.7897
#
# Epoch 00083: val_acc did not improve from 0.79150
# Epoch 84/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0018 - acc: 0.9997 - val_loss: 1.3034 - val_acc: 0.7909
#
# Epoch 00084: val_acc did not improve from 0.79150
# Epoch 85/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0019 - acc: 0.9997 - val_loss: 1.3116 - val_acc: 0.7882
#
# Epoch 00085: val_acc did not improve from 0.79150
# Epoch 86/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0017 - acc: 0.9997 - val_loss: 1.3189 - val_acc: 0.7893
#
# Epoch 00086: val_acc did not improve from 0.79150
# Epoch 87/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0020 - acc: 0.9997 - val_loss: 1.3298 - val_acc: 0.7889
#
# Epoch 00087: val_acc did not improve from 0.79150
# Epoch 88/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0016 - acc: 0.9997 - val_loss: 1.3209 - val_acc: 0.7877
#
# Epoch 00088: val_acc did not improve from 0.79150
# Epoch 89/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0019 - acc: 0.9996 - val_loss: 1.3177 - val_acc: 0.7878
#
# Epoch 00089: val_acc did not improve from 0.79150
# Epoch 90/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0017 - acc: 0.9996 - val_loss: 1.3274 - val_acc: 0.7895
#
# Epoch 00090: val_acc did not improve from 0.79150
# Epoch 91/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0017 - acc: 0.9998 - val_loss: 1.3226 - val_acc: 0.7909
#
# Epoch 00091: val_acc did not improve from 0.79150
# Epoch 92/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0017 - acc: 0.9997 - val_loss: 1.3272 - val_acc: 0.7920
#
# Epoch 00092: val_acc improved from 0.79150 to 0.79200, saving model to /content/drive/My Drive/assignment_5_resnet_cifar10.h5
# Epoch 93/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0014 - acc: 0.9998 - val_loss: 1.3303 - val_acc: 0.7902
#
# Epoch 00093: val_acc did not improve from 0.79200
# Epoch 94/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0018 - acc: 0.9997 - val_loss: 1.3222 - val_acc: 0.7899
#
# Epoch 00094: val_acc did not improve from 0.79200
# Epoch 95/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0017 - acc: 0.9997 - val_loss: 1.3231 - val_acc: 0.7901
#
# Epoch 00095: val_acc did not improve from 0.79200
# Epoch 96/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0017 - acc: 0.9996 - val_loss: 1.3274 - val_acc: 0.7908
#
# Epoch 00096: val_acc did not improve from 0.79200
# Epoch 97/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0016 - acc: 0.9997 - val_loss: 1.3244 - val_acc: 0.7912
#
# Epoch 00097: val_acc did not improve from 0.79200
# Epoch 98/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0020 - acc: 0.9997 - val_loss: 1.3414 - val_acc: 0.7900
#
# Epoch 00098: val_acc did not improve from 0.79200
# Epoch 99/100
# 390/390 [==============================] - 16s 41ms/step - loss: 0.0016 - acc: 0.9997 - val_loss: 1.3331 - val_acc: 0.7928
#
# Epoch 00099: val_acc improved from 0.79200 to 0.79280, saving model to /content/drive/My Drive/assignment_5_resnet_cifar10.h5
# Epoch 100/100
# 390/390 [==============================] - 16s 42ms/step - loss: 0.0015 - acc: 0.9997 - val_loss: 1.3258 - val_acc: 0.7911
#
# Epoch 00100: val_acc did not improve from 0.79280
# Model took 1673.59 seconds to train
# Accuracy on test data is: 79.11

# %% [markdown]
# ## Get the validation accuracy of Best  model generated duringTraining

# %%
from keras.models import load_model

# Load the best model
model_save_path= "/content/drive/My Drive/assignment_5_resnet_cifar10.h5"
best_model = load_model(model_save_path)

# compute test accuracy on best model
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, best_model))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0717 02:11:50.787191 139679555946368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0717 02:11:50.847345 139679555946368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0717 02:11:50.848744 139679555946368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0717 02:11:50.849773 139679555946368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0717 02:11:50.851339 139679555946368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0717 02:11:53.826913 139679555946368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0717 02:11:54.137909 139679555946368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0717 02:11:57.392029 139679555946368 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0717 02:11:57.518276 139679555946368 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Accuracy on test data is: 79.28

# %% [markdown]
# ## Create a pandas dataframe which will have true class index and predicted class index

# %%
import pandas as pd


result = best_model.predict(test_features)
predicted_class = np.argmax(result, axis=1)
true_class = np.argmax(test_labels, axis=1)

# Define pandas dataframe df with Two fields true_class for storing Actual class index
# and predicted_class for storing Predicted Class Index
df = pd.DataFrame({ "true_class": true_class, "predicted_class": predicted_class })

# %%
df
# Out:
#       true_class  predicted_class
# 0              3                3
# 1              8                8
# 2              8                8
# 3              0                8
# 4              6                6
# 5              6                6
# 6              1                1
# 7              6                6
# 8              3                3
# 9              1                1
# 10             0                0
# 11             9                9
# 12             5                5
# 13             7                7
# 14             9                9
# 15             8                1
# 16             5                5
# 17             7                7
# 18             8                8
# 19             6                6
# 20             7                9
# 21             0                0
# 22             4                4
# 23             9                9
# 24             5                4
# 25             2                2
# 26             4                4
# 27             0                2
# 28             9                9
# 29             6                6
# ...          ...              ...
# 9970           2                2
# 9971           9                9
# 9972           4                4
# 9973           0                0
# 9974           1                1
# 9975           7                7
# 9976           5                5
# 9977           5                5
# 9978           7                4
# 9979           3                3
# 9980           0                0
# 9981           4                7
# 9982           2                4
# 9983           0                1
# 9984           7                4
# 9985           5                9
# 9986           8                8
# 9987           0                0
# 9988           8                8
# 9989           2                4
# 9990           7                7
# 9991           0                0
# 9992           3                3
# 9993           5                3
# 9994           3                3
# 9995           8                0
# 9996           3                5
# 9997           5                5
# 9998           1                1
# 9999           7                7
#
# [10000 rows x 2 columns]

# %% [markdown]
# ## Find the misclassified images
#
#  *   Apply query on data pandas dataframe df for records for which true_class field value does not match with predicted_class field value and get a new dataframe of misclassified images.

# %%
misclassified_df = df[df["true_class"] != df["predicted_class"]]

# %%
misclassified_df.shape
# Out:
# (2072, 2)

# %%
print("Total number of misclassified images: " + str(misclassified_df.shape[0]))
# Out:
# Total number of misclassified images: 2072

# %% [markdown]
# ## Observation
# As number of misclassified images are 2072 which matches with Validation accuracy of 79.28 which should give  2072 misclassified images

# %% [markdown]
# ## Define a method for GradCam
# Define a method get_gradcam_image which will take the pixel normalized image, model, layer name and return the gradcam image
#
# The steps are as below:
# * Import OpenCV library cv2
# * Use expand_dims to convert image to a batch of size 1
# *  Get the predictions for the input image
# * Take the topmost class index
# * Take output from the given convolution layer
# *  Compute the gradient of the class output value with respect to the feature map
# *  Pool the gradients over all the axies leaving out the channel dimension
# * Weigh the output feature map with the computed gradient values
# *  Average the weighted feature map along the channel dimension resulting in a heatmap of first two dimensions equal to original image first two dimensions
# *  Normalize the heat map to make the values between 0 and 1
# * Multiply the pixel values of original image by 255
# * Use addWeighted method of cv2 by giving the scaled input image and the heat map at 50% basis to create the superimposed image

# %%
import cv2

def get_gradcam_image(orig_std_image, model, layer_name):
  
  x = np.expand_dims(orig_std_image, axis=0)
  preds = model.predict(x)
  class_idx = np.argmax(preds[0])
  class_output = model.output[:, class_idx]
  conv_layer = model.get_layer(layer_name)


  grads = K.gradients(class_output, conv_layer.output)[0]
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  iterate = K.function([model.input], [pooled_grads, conv_layer.output[0]])
  pooled_grads_value, conv_layer_output_value = iterate([x])
  
  no_of_channels = conv_layer.get_weights()[0].shape[-1]
  for i in range(no_of_channels):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]

  heatmap = np.mean(conv_layer_output_value, axis=-1)
  heatmap = np.maximum(heatmap, 1e-7)
  heatmap /= np.max(heatmap)

 
  heatmap = cv2.resize(heatmap, (orig_std_image.shape[1], orig_std_image.shape[0]))
  heatmap = np.uint8(255 * heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)



  orig_image= np.uint8(255 * (orig_std_image))

  superimposed_img = cv2.addWeighted(orig_image, 0.5, heatmap, 0.5, 0)
  return superimposed_img

# %% [markdown]
# ## Display GradCam results on layer stage2_unit2_conv2 for 50 misclassified images
#
# * From the misclassified dataframe get list of 50 records
# * Iterate over 50 records misclassified test image dataframe
# * For each misclassified test image record, get the original image
# * Use get_gradcam_image by passing input as original test image, best model, layer as stage2_unit2_conv2 to get teh superimosed image
# * In each row display first the original image with True and predicted class followed by gradcam image with True class name
#
# Note: I have chosen stage2_unit2_conv2 as it has image size 4x4 which can be used for generating heatmap

# %%
# Created a dataframe misclassified_display_df of 50 misclassified images
misclassified_50_df = misclassified_df.head(50)

# Actual numeric actual label values
actual_labels = np.argmax(test_labels, axis=1)

# Iterate over each of 50 misclssified images
for index, row in misclassified_50_df.iterrows() :
    test_image = test_features[index]
  
    # get the GradCam superimposed image by passing test image, best_model and stage2_unit2_conv2 as layer to get_gradcam_image method
    superimposed_img = get_gradcam_image(test_image, best_model, "stage2_unit2_conv2")

    # Display the original test image
    fig=plt.figure(figsize=(4, 4))
    columns = 2
    rows = 1
    ax = fig.add_subplot(rows, columns, 1)
    ax.axis('off')
    ax.set_title("               True: " + str(class_names[row["true_class"]]) + ", Predicted: " + str(class_names[row["predicted_class"]]) + "  gradCAM:" + str(class_names[row["true_class"]]))
    plt.imshow(test_image)
  
    # Display the superimposed GradCam image
    fig.add_subplot(rows, columns, 2)
    #ax.axis('off')
    plt.imshow(superimposed_img)
    plt.show()

# %% [markdown]
# ## Final Observations:
#
# In this assignment:
#
# - I have first loaded a pretrained RESNET18 model on imagenet
# - Used transfer learning to trainthe model on CIFAR 10 dataset
# - Got a accuracy of 79.28 on the model
# - Get a list of 50 misclassified images
# - Get gradCAM on the misclassified images and create a gallery by showing original image and gradCAM result in each row
